# %%
import pandas as pd

# %%
yearly_zillow_df=pd.read_csv('yearlyavg-v2.csv')

# %%
yearly_zillow_df
# Out:
#      RegionID  SizeRank          RegionName State           City      2000  \
# 0      417523      6738        Alamo Square    CA  San Francisco  476872.8
# 1      417521     11352          Anza Vista    CA  San Francisco  477060.6
# 2      786321     10635        Aquatic Park    CA  San Francisco       NaN
# 3      786329      7112     Ashbury Heights    CA  San Francisco  790854.0
# 4      417508     16011      Balboa Terrace    CA  San Francisco  854899.2
# ..        ...       ...                 ...   ...            ...       ...
# 103    268570      1213   Visitacion Valley    CA  San Francisco  374649.3
# 104    786326      5332         West Portal    CA  San Francisco  595423.0
# 105    118904      1143    Western Addition    CA  San Francisco  458316.6
# 106    417513     20416  Westwood Highlands    CA  San Francisco  673549.5
# 107    417510      9820       Westwood Park    CA  San Francisco  592936.7
#
# ...
